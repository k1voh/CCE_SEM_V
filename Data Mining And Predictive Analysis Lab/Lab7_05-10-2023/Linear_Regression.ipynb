# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("E:\\Language\\Data Mining And Predictive Analysis Lab\\Lab7_05-10-2023\\Dataset.csv")

# %%
data.head()
# Out:
#    HEIGHT  WEIGHT
# 0     185      72
# 1     170      56
# 2     168      60
# 3     179      68
# 4     182      72

# %%
dataset = data.values.tolist()
dataset
# Out:
# [[185, 72], [170, 56], [168, 60], [179, 68], [182, 72]]

# %%
X_list = [x[0] for x in dataset]
Y_list = [y[1] for y in dataset]

plt.scatter(X_list,Y_list)

# %%
def calculate_coeff(x,y):
    x2 = [x*x for x in x]
    xy = [x*y[i] for i,x in enumerate(x)]
    n = np.size(x)
    a = ((np.sum(y) * np.sum(x2)) - (np.sum(x) * np.sum(xy))) / ((n * np.sum(x2)) - np.square(np.sum(x)))
    b = (((n * np.sum(xy)) - np.sum(x) * np.sum(y)) / ((n * np.sum(x2)) - np.square(np.sum(x))))
    
    return b,a

# %%
def plot():
    m,c = calculate_coeff(X_list,Y_list)
    plt.scatter(X_list,Y_list,color='red')
    new_y = [m*x + c for x in X_list]
    plt.plot(X_list,new_y,color='black')
    plt.ylabel('Weight')
    plt.xlabel('Height')
    plt.title('Linear Regression')
    plt.show()

# %%
def predict(height):
    m,c = calculate_coeff(X_list,Y_list)
    plot()
    new_weight = m*height + c
    return new_weight

# %%
height = int(input("Enter the height you want to predict the weight for : "))
print(round(predict(height)))
# Out:
# 64
